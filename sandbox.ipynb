# %%
import requests
import pandas as pd
from credentials import key
from datetime import datetime

# %%
lat = 40.711017
long = -74.016937

# %%
url = f'https://api.darksky.net/forecast/d131dc9bc523abbcd427cb5bed55182e/{lat},{long}'

# %%
r = requests.get(url)

# %%
df = pd.DataFrame(eval(r.text)['hourly']['data'])

# %%
df['timestamp'] = [datetime.utcfromtimestamp(ts) for ts in df['time']]
df['date'] = [i.date() for i in df['timestamp']]

# %%
df.head()
# Out:
#    apparentTemperature  cloudCover  dewPoint  humidity               icon  \
# 0                30.37        0.89     19.51      0.47  partly-cloudy-day
# 1                32.02        0.90     20.22      0.45  partly-cloudy-day
# 2                33.71        0.82     21.23      0.45  partly-cloudy-day
# 3                35.95        0.35     24.15      0.48  partly-cloudy-day
# 4                37.50        0.07     25.77      0.49          clear-day
#
#     ozone  precipAccumulation  precipIntensity  precipProbability precipType  \
# 0  389.10                 NaN           0.0000               0.00        NaN
# 1  386.13                 NaN           0.0000               0.00        NaN
# 2  382.82                 NaN           0.0000               0.00        NaN
# 3  379.77                 NaN           0.0000               0.00        NaN
# 4  377.37                 NaN           0.0013               0.08       rain
#
# ...
